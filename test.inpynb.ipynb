# %%
import networkx as nx
import time
from itertools import combinations
from pathlib import Path

# %run steiner.ipynb

# %%
## Test on Small Examples

def test_algorithm(algorithm, files, is_exact=False):
    for filepath in files:
        G, terminals, name = parse_stp(filepath)
        print(f'--- {name} ---')
        print(f'Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}, Terminals: {len(terminals)}')

        start = time.time()
        if is_exact:
            tree, weight, subsets = algorithm(G, terminals)
            print(f'Subsets checked: {subsets}')
        else:
            tree, weight = algorithm(G, terminals)
        elapsed = time.time() - start

        steiner_points = [v for v in tree.nodes() if v not in terminals]
        print(f'Weight: {weight}')
        print(f'Steiner points used: {steiner_points}')
        print(f'Edges: {list(tree.edges(data=True))}')
        print(f'Time: {elapsed:.4f}s')
        print()

# %%
small_files = sorted(Path('data/small').glob('*.stp'))

print('--BRUTE FORCE--')
test_algorithm(brute_force_steiner, small_files, is_exact=True)

print('--MST HEURISTIC--')
test_algorithm(mst_heuristic, small_files)

print('--MEHLHORN--')
test_algorithm(mehlhorn_steiner, small_files)

print('--SPH--')
test_algorithm(sph_steiner, small_files)

print('--ZELIKOVSKY--')
test_algorithm(zelikovsky_steiner, small_files)
# Out:
# --BRUTE FORCE--
# --- small01 ---
# Nodes: 5, Edges: 7, Terminals: 3
# Subsets checked: 4
# Weight: 7.0
# Steiner points used: [2, 4]
# Edges: [(1, 2, {'weight': 2}), (2, 4, {'weight': 1}), (2, 3, {'weight': 2}), (4, 5, {'weight': 2})]
# Time: 0.0005s
#
# --- small02 ---
# Nodes: 10, Edges: 15, Terminals: 4
# Subsets checked: 64
# Weight: 19.0
# Steiner points used: [2, 5, 8, 9]
# Edges: [(1, 2, {'weight': 3}), (2, 5, {'weight': 4}), (4, 5, {'weight': 2}), (5, 8, {'weight': 3}), (7, 8, {'weight': 2}), (8, 9, {'weight': 2}), (9, 10, {'weight': 3})]
# Time: 0.0035s
#
# --- small03 ---
# Nodes: 15, Edges: 25, Terminals: 5
# Subsets checked: 1024
# Weight: 32.0
# Steiner points used: [2, 4, 6, 8, 10, 11, 13]
# Edges: [(1, 2, {'weight': 3}), (2, 4, {'weight': 4}), (4, 6, {'weight': 2}), (4, 5, {'weight': 3}), (6, 8, {'weight': 3}), (8, 9, {'weight': 2}), (8, 10, {'weight': 3}), (10, 11, {'weight': 2}), (10, 13, {'weight': 4}), (11, 12, {'weight': 3}), (13, 15, {'weight': 3})]
# Time: 0.0784s
#
# --MST HEURISTIC--
# --- small01 ---
# Nodes: 5, Edges: 7, Terminals: 3
# Weight: 7.0
# Steiner points used: [2, 4]
# Edges: [(1, 2, {'weight': 2}), (2, 4, {'weight': 1}), (2, 3, {'weight': 2}), (4, 5, {'weight': 2})]
# Time: 0.0002s
#
# --- small02 ---
# Nodes: 10, Edges: 15, Terminals: 4
# Weight: 21.0
# Steiner points used: [2, 5, 8, 9]
# Edges: [(1, 2, {'weight': 3}), (2, 5, {'weight': 4}), (5, 4, {'weight': 2}), (5, 7, {'weight': 5}), (7, 8, {'weight': 2}), (8, 9, {'weight': 2}), (9, 10, {'weight': 3})]
# Time: 0.0002s
#
# --- small03 ---
# Nodes: 15, Edges: 25, Terminals: 5
# Weight: 39.0
# Steiner points used: [2, 4, 6, 8, 10, 11, 14]
# Edges: [(1, 2, {'weight': 3}), (2, 4, {'weight': 4}), (4, 5, {'weight': 3}), (5, 6, {'weight': 5}), (6, 8, {'weight': 3}), (8, 9, {'weight': 2}), (9, 10, {'weight': 5}), (10, 11, {'weight': 2}), (11, 12, {'weight': 3}), (12, 14, {'weight': 4}), (14, 15, {'weight': 5})]
# Time: 0.0004s
#
# --MEHLHORN--
# --- small01 ---
# Nodes: 5, Edges: 7, Terminals: 3
# Weight: 7.0
# Steiner points used: [2, 4]
# Edges: [(1, 2, {'weight': 2}), (2, 4, {'weight': 1}), (2, 3, {'weight': 2}), (5, 4, {'weight': 2})]
# Time: 0.0002s
#
# --- small02 ---
# Nodes: 10, Edges: 15, Terminals: 4
# Weight: 21.0
# Steiner points used: [2, 5, 8, 9]
# Edges: [(1, 2, {'weight': 3}), (2, 5, {'weight': 4}), (4, 5, {'weight': 2}), (5, 7, {'weight': 5}), (7, 8, {'weight': 2}), (8, 9, {'weight': 2}), (10, 9, {'weight': 3})]
# Time: 0.0002s
#
# --- small03 ---
# Nodes: 15, Edges: 25, Terminals: 5
# Weight: 39.0
# Steiner points used: [2, 4, 13, 6, 8, 10, 11]
# Edges: [(1, 2, {'weight': 3}), (2, 4, {'weight': 4}), (5, 4, {'weight': 3}), (5, 6, {'weight': 5}), (15, 13, {'weight': 3}), (13, 12, {'weight': 6}), (12, 11, {'weight': 3}), (6, 8, {'weight': 3}), (9, 8, {'weight': 2}), (9, 10, {'weight': 5}), (10, 11, {'weight': 2})]
# Time: 0.0004s
#
# --SPH--
# --- small01 ---
# Nodes: 5, Edges: 7, Terminals: 3
# Weight: 7.0
# Steiner points used: [2, 4]
# Edges: [(1, 2, {'weight': 2}), (2, 4, {'weight': 1}), (2, 3, {'weight': 2}), (4, 5, {'weight': 2})]
# Time: 0.0001s
#
# --- small02 ---
# Nodes: 10, Edges: 15, Terminals: 4
# Weight: 21.0
# Steiner points used: [2, 5, 8, 9]
# Edges: [(1, 2, {'weight': 3}), (2, 5, {'weight': 4}), (5, 4, {'weight': 2}), (5, 7, {'weight': 5}), (7, 8, {'weight': 2}), (8, 9, {'weight': 2}), (9, 10, {'weight': 3})]
# Time: 0.0003s
#
# --- small03 ---
# Nodes: 15, Edges: 25, Terminals: 5
# Weight: 32.0
# Steiner points used: [2, 4, 6, 8, 10, 11, 13]
# Edges: [(1, 2, {'weight': 3}), (2, 4, {'weight': 4}), (4, 6, {'weight': 2}), (4, 5, {'weight': 3}), (6, 8, {'weight': 3}), (8, 9, {'weight': 2}), (8, 10, {'weight': 3}), (10, 11, {'weight': 2}), (10, 13, {'weight': 4}), (11, 12, {'weight': 3}), (13, 15, {'weight': 3})]
# Time: 0.0009s
#
# --ZELIKOVSKY--
# --- small01 ---
# Nodes: 5, Edges: 7, Terminals: 3
# Weight: 7.0
# Steiner points used: [2, 4]
# Edges: [(1, 2, {'weight': 2}), (2, 4, {'weight': 1}), (2, 3, {'weight': 2}), (4, 5, {'weight': 2})]
# Time: 0.0004s
#
# --- small02 ---
# Nodes: 10, Edges: 15, Terminals: 4
# Weight: 21.0
# Steiner points used: [2, 5, 8, 9, 6]
# Edges: [(1, 2, {'weight': 3}), (2, 5, {'weight': 4}), (5, 6, {'weight': 1}), (5, 4, {'weight': 2}), (7, 8, {'weight': 2}), (8, 9, {'weight': 2}), (9, 10, {'weight': 3}), (9, 6, {'weight': 4})]
# Time: 0.0017s
#
# --- small03 ---
# Nodes: 15, Edges: 25, Terminals: 5
# Weight: 32.0
# Steiner points used: [2, 4, 6, 8, 10, 11, 13]
# Edges: [(1, 2, {'weight': 3}), (2, 4, {'weight': 4}), (4, 6, {'weight': 2}), (4, 5, {'weight': 3}), (6, 8, {'weight': 3}), (8, 9, {'weight': 2}), (8, 10, {'weight': 3}), (10, 11, {'weight': 2}), (10, 13, {'weight': 4}), (11, 12, {'weight': 3}), (15, 13, {'weight': 3})]
# Time: 0.0114s
